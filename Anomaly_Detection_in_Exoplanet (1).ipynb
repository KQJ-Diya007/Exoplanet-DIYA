# %% [markdown]
# # Unsupervised Learning Framework for Anomaly Detection in Exoplanet Data

# %%
# Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn.ensemble import IsolationForest
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Loading the Dataset

# %%
# CSV structure: ['planet_radius', 'orbital_period', 'stellar_temp', 'flux_received', 'eccentricity']
data = pd.read_csv("exoplanet_features.csv")

# %% [markdown]
# 2. Data Preprocessing

# %%
features = data.select_dtypes(include=[np.number]).dropna()
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %% [markdown]
# 3. Dimensionality Reduction

# %%
pca = PCA(n_components=3)
pca_features = pca.fit_transform(scaled_features)

# %% [markdown]
# 4. Anomaly Detection with Isolation Forest

# %%
iso_forest = IsolationForest(contamination=0.05, random_state=42)
data['anomaly_score'] = iso_forest.fit_predict(pca_features)
data['anomaly'] = data['anomaly_score'] == -1

# %% [markdown]
# 5. Clustering with DBSCAN for Group Anomalies

# %%
db = DBSCAN(eps=0.5, min_samples=5)
data['cluster'] = db.fit_predict(pca_features)

# %% [markdown]
# 6. t-SNE for Visualisation

# %%
# tsne = TSNE(n_components=2, perplexity=30, n_iter=3000, random_state=42)
# tsne = TSNE(n_components=2, perplexity=3, n_iter=3000, random_state=42)
tsne = TSNE(n_components=2, perplexity=3, max_iter=3000, random_state=42)
tsne_results = tsne.fit_transform(pca_features)
data['tsne-1'] = tsne_results[:, 0]
data['tsne-2'] = tsne_results[:, 1]

# %% [markdown]
# 7. Visualisation

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='tsne-1', y='tsne-2', hue='anomaly', data=data, palette={True: 'red', False: 'blue'}, alpha=0.7)
plt.title("Exoplanet Anomaly Detection via Unsupervised Learning")
plt.legend(title='Anomaly')
plt.show()

# %% [markdown]
# 8. Saving Anomalies for further use

# %%
anomalies = data[data['anomaly'] == True]
anomalies.to_csv("flagged_exoplanet_anomalies.csv", index=False)

# %% [markdown]
# 3D Interactive Visual of Exoplanet

# %%
import plotly.express as px

# Loading the processed dataset
df = pd.read_csv("flagged_exoplanet_anomalies.csv")

required_cols = ['planet_radius', 'orbital_period', 'stellar_temp', 'anomaly']
if not all(col in df.columns for col in required_cols):
    raise ValueError("Dataset must contain planet_radius, orbital_period, stellar_temp, and anomaly columns.")

# Plotly 3D scatter plot
fig = px.scatter_3d(
    df,
    x='planet_radius',
    y='orbital_period',
    z='stellar_temp',
    color='anomaly',
    symbol='anomaly',
    title='3D Interactive Visualisation of Exoplanets',
    labels={'planet_radius': 'Radius (R⊕)', 'orbital_period': 'Orbital Period (days)', 'stellar_temp': 'Stellar Temp (K)'},
     # Show all info when hovered
    hover_data=df.columns
)

fig.update_traces(marker=dict(size=6))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d2abd200-05a4-4755-abfa-027d4abaf2d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2abd200-05a4-4755-abfa-027d4abaf2d9")) {                    Plotly.newPlot(                        "d2abd200-05a4-4755-abfa-027d4abaf2d9",                        [{"customdata":[[5.2,0.7,-1,true,-1,-18.034203,58.284542]],"hovertemplate":"anomaly=%{customdata[3]}\u003cbr\u003eRadius (R⊕)=%{x}\u003cbr\u003eOrbital Period (days)=%{y}\u003cbr\u003eStellar Temp (K)=%{z}\u003cbr\u003eflux_received=%{customdata[0]}\u003cbr\u003eeccentricity=%{customdata[1]}\u003cbr\u003eanomaly_score=%{customdata[2]}\u003cbr\u003ecluster=%{customdata[4]}\u003cbr\u003etsne-1=%{customdata[5]}\u003cbr\u003etsne-2=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#636efa","symbol":"circle","size":6},"mode":"markers","name":"True","scene":"scene","showlegend":true,"x":[6.0],"y":[18],"z":[2900],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar" ...

# %% [markdown]
# Pair Grid

# %%
sns.pairplot(data, hue="anomaly", vars=['planet_radius', 'orbital_period', 'stellar_temp'])

# %% [markdown]
# The Feature Correlation Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Feature - Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Feature - Correlation Matrix')

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x='anomaly', y='planet_radius', data=data)
# Out:
# <Axes: xlabel='anomaly', ylabel='planet_radius'>

# %%
sns.kdeplot(data=data, x="orbital_period", hue="anomaly", fill=True)
# Out:
# <ipython-input-40-bdc58fb65ed8>:1: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
# <Axes: xlabel='orbital_period', ylabel='Density'>

# %%
sns.histplot(data['anomaly_score'], bins=20, kde=True)
# Out:
# <Axes: xlabel='anomaly_score', ylabel='Count'>

# %% [markdown]
# # Using Kepler Dataset

# %%
kepler_data = pd.read_csv("kepler_dataset.csv")

kepler_data.head(), kepler_data.columns
# Out:
# (   koi_fpflag_nt  koi_fpflag_co  koi_fpflag_ss  koi_fpflag_ec  koi_period  \
#  0              0              1              0              1   32.440348
#  1              1              0              1              1   33.462393
#  2              0              0              1              1   45.470422
#  3              0              0              1              1   57.347310
#  4              0              0              1              0   68.271693
#
#     koi_count   koi_time0  koi_disposition
#  0          3  133.418728                1
#  1          3  138.362896                1
#  2          2  145.145660               -1
#  3          2  147.959293               -1
#  4          1  131.682553                1  ,
#  Index(['koi_fpflag_nt', 'koi_fpflag_co', 'koi_fpflag_ss', 'koi_fpflag_ec',
#         'koi_period', 'koi_count', 'koi_time0', 'koi_disposition'],
#        dtype='object'))

# %% [markdown]
# 1. Selecting features and scaling them

# %%
features = kepler_data.drop(columns=['koi_disposition'])
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %% [markdown]
# 2. Applying PCA for dimensionality reduction

# %%
pca = PCA(n_components=3)
pca_features = pca.fit_transform(scaled_features)

# %% [markdown]
#  3. Applying Isolation Forest for anomaly detection

# %%
iso_forest = IsolationForest(contamination=0.05, random_state=42)
kepler_data['anomaly_score'] = iso_forest.fit_predict(pca_features)
kepler_data['anomaly'] = kepler_data['anomaly_score'] == -1

# %% [markdown]
# 4. Applying t-SNE for visualisation

# %%
tsne = TSNE(n_components=2, perplexity=3, random_state=42, max_iter=3000)
tsne_results = tsne.fit_transform(pca_features)
kepler_data['tsne-1'] = tsne_results[:, 0]
kepler_data['tsne-2'] = tsne_results[:, 1]

# %% [markdown]
# 5. Plotting the results

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x='tsne-1', y='tsne-2', hue='anomaly', data=kepler_data, palette={True: 'red', False: 'blue'})
plt.title("Anomaly Detection in Kepler Dataset using Isolation Forest + t-SNE")
plt.legend(title="Anomaly")
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Preparing PCA DataFrame

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, perplexity=3, max_iter=500, random_state=42)
tsne_results = tsne.fit_transform(pca_features)
kepler_data['tsne-1'] = tsne_results[:, 0]
kepler_data['tsne-2'] = tsne_results[:, 1]

pca_df = pd.DataFrame(pca_features, columns=['PCA1', 'PCA2', 'PCA3'])
pca_df['anomaly'] = kepler_data['anomaly']

# %% [markdown]
# 7. Plotting t-SNE scatter and anomaly count

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6))
sns.scatterplot(x='tsne-1', y='tsne-2', hue='anomaly', data=kepler_data, palette={True: 'red', False: 'blue'}, ax=axs[0])
axs[0].set_title("t-SNE Anomaly Visualisation")
cluster_counts = kepler_data['anomaly'].value_counts()
axs[1].bar(cluster_counts.index.astype(str), cluster_counts.values, color=['blue', 'red'])
axs[1].set_title("Anomaly Counts")
axs[1].set_xlabel("Anomaly")
axs[1].set_ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# Feature  Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = pd.DataFrame(scaled_features, columns=features.columns).corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature - Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# Pairplot

# %%
sns.pairplot(pca_df, hue='anomaly', palette={True: 'red', False: 'blue'})
plt.suptitle("PCA Pairplot with Anomaly Labels", y=1.02)
plt.show()

# %%
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='variable', y='value', hue='anomaly', data=melted_box_data, palette={True: 'red', False: 'blue'})
# plt.title("Feature Distributions by Anomaly Status (Cleaned Data)")
# plt.xlabel("Feature")
# plt.ylabel("Value")
# plt.legend(title="Anomaly")
# plt.tight_layout()
# plt.show()

# %%
# sns.pairplot(numeric_pca, hue='anomaly', palette={'True': 'red', 'False': 'blue'}, diag_kind="hist")
# plt.suptitle("PCA Pairplot with Anomaly Labels (Histogram Diagonals)", y=1.02)
# plt.show()
